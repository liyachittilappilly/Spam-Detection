# %% [markdown]
# <a href="https://colab.research.google.com/github/liyachittilappilly/Spam-Detection/blob/main/SpamorNot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ![How to Stop Spam Emails and Get Rid of Them….jpg](data:image/jpeg;base64,...)
#
#  building two ml models to predict whether an email is spam or not
#
#  models used are:
#
# 1.   Random Forest Classifier
# 2.   AdaBoost Classifier

# %%
import pandas as pd
d = pd.read_csv("/content/spambase.csv")

from sklearn.model_selection import train_test_split
X=d[d.columns.drop('spam')]
Y=d['spam']
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=100)
# Out:
# 0.8535326086956522 0.8545059717698155

# %% [markdown]
# ![Screenshot 2025-06-26 225505.png](data:image/png;base64,...)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=10,  min_samples_split=20, min_impurity_decrease=0.05)
model.fit(X_train,Y_train)

train_accuracy = model.score(X_train,Y_train)
test_accuracy = model.score(X_test,Y_test)
print(train_accuracy,test_accuracy)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
feature_imps = pd.DataFrame(np.array([features,  model.feature_importances_]).T,  columns=["feature","importance"])
feature_imps.sort_values(by="importance",ascending=False)
# Out:
#                        feature importance
# 23             word_freq_money   0.202405
# 52                 char_freq_$   0.139077
# 54  capital_run_length_average   0.133218
# 51                 char_freq_!        0.1
# 2                word_freq_all        0.1
# 20              word_freq_your        0.1
# 6             word_freq_remove   0.064376
# 15              word_freq_free   0.060923
# 24                word_freq_hp   0.058115
# 7           word_freq_internet   0.041885
# 39            word_freq_direct        0.0
# 40                word_freq_cs        0.0
# 0               word_freq_make        0.0
# 38                word_freq_pm        0.0
# 37             word_freq_parts        0.0
# 36              word_freq_1999        0.0
# 35        word_freq_technology        0.0
# 34                word_freq_85        0.0
# 41           word_freq_meeting        0.0
# 45               word_freq_edu        0.0
# 42          word_freq_original        0.0
# ...

# %% [markdown]
#  ![image.png](data:image/png;base64,...)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier

model = AdaBoostClassifier(n_estimators=10)
model.fit(X_train,Y_train)

train_accuracy = model.score(X_train,Y_train)
test_accuracy = model.score(X_test,Y_test)
print(train_accuracy,test_accuracy)
# Out:
# 0.9067934782608695 0.9131378935939196

# %%
feature_imps = pd.DataFrame(np.array([features, model.feature_importances_]).T, columns=["feature","importance"])
#.T flips it to N x 2 shape
feature_imps.sort_values(by="importance",ascending=False)
# Out:
#                        feature importance
# 52                 char_freq_$   0.181293
# 51                 char_freq_!   0.154507
# 24                word_freq_hp   0.123299
# 6             word_freq_remove   0.119936
# 15              word_freq_free   0.109165
# 36              word_freq_1999   0.101538
# 26            word_freq_george    0.09101
# 55  capital_run_length_longest   0.078189
# 45               word_freq_edu   0.041064
# 34                word_freq_85        0.0
# 41           word_freq_meeting        0.0
# 35        word_freq_technology        0.0
# 33               word_freq_415        0.0
# 37             word_freq_parts        0.0
# 38                word_freq_pm        0.0
# 39            word_freq_direct        0.0
# 40                word_freq_cs        0.0
# 0               word_freq_make        0.0
# 42          word_freq_original        0.0
# 43           word_freq_project        0.0
# 31               word_freq_857        0.0
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)
